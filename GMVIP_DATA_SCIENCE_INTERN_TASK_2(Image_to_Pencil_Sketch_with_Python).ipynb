# %% [markdown]
# <a href="https://colab.research.google.com/github/kishanhaldar78/LGMVIP/blob/main/GMVIP_DATA_SCIENCE_INTERN_TASK_2(Image_to_Pencil_Sketch_with_Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**LET'S GROW MORE**
#
# **Name :** Kishan Haldar
#
# **Task-2:** Image to Pencil Sketch with Python
#
# **Description Of Task:**
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
# **Reference :** https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %% [markdown]
# **Importing Libraries**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Reading and display uploaded Image**

# %%
uploaded = files.upload()
name=[]

for fn in uploaded.keys():
  name.append(fn)

newName='/content/'+name[0]
img = cv2.imread(newName)
cv2_imshow(img)
# Out:
#      <input type="file" id="files-dd342fe9-290f-42c2-bd93-8441e5d4fba3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd342fe9-290f-42c2-bd93-8441e5d4fba3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving apple.jfif to apple.jfif
# <PIL.Image.Image image mode=RGB size=1000x750 at 0x7F25F43D7B90>

# %% [markdown]
# **Converting to Grayscale**

# %%
gray_img = cv2.imread(newName,0)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F25F5591D90>

# %% [markdown]
# **Inverting Image**

# %%
inverted_img = 255 - gray_img
cv2_imshow(inverted_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F25EF99BE90>

# %% [markdown]
# **Blurring the Image**

# %%
blur_img = cv2.GaussianBlur(inverted_img,(15,15),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F25EF99B0D0>

# %% [markdown]
# **Presenting the Final Pencil Sketch**

# %%
inverted_blur_img = 255 - blur_img
pencil_sketch = cv2.divide(gray_img,inverted_blur_img,scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F25EFB0B9D0>
